# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 구글 드라이브 상에 코드 배포했던 저장위치로 이동

# %%
cd /content/drive/MyDrive/GUARD_EXP_REPO
# Out:
# /content/drive/MyDrive/GUARD_EXP_REPO

# %%
ls
# Out:
# bench1.ipynb  config/  data/  doc/  model/  readme.md  utils/

# %% [markdown]
# 아래 스크립트로 프로젝트 의존성 맞추면 됨

# %%
# !sh setting.sh
# Out:
# sh: 0: cannot open setting.sh: No such file

# %% [markdown]
# 다음 유틸로 영상 다운로드 가능 (롱이든 숏이든 다)

# %%
# !python -m utils.download https://www.youtube.com/shorts/Mcst74e8S9U
# Out:
# [youtube] Extracting URL: https://www.youtube.com/shorts/Mcst74e8S9U
# [youtube] Mcst74e8S9U: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] Mcst74e8S9U: Downloading android vr player API JSON
# [info] Mcst74e8S9U: Downloading 1 format(s): 137+140
# [download] /content/drive/MyDrive/GUARD_EXP_REPO/data/Mcst74e8S9U.mp4 has already been downloaded
# Saved video to: /content/drive/MyDrive/GUARD_EXP_REPO/data/Mcst74e8S9U.mp4

# %%
# ./data에 저장된 영상 경로 확인, 혹시 모르니 코랩 익스텐션에 마운트된 구글 드라이브 상황까지 확인 해보기
# !ls ./data
# Out:
# Mcst74e8S9U.mp4

# %%
# 아래와 같이 .yaml 수정 없이 바로 cli로 옵션 선택 가능
# 모델 로드가 너무 느려지면 ./model/repo 지우고 그냥 새로 다운하는걸 추천 (왼쪽에 코랩 익스텐션에서도 삭제가 가능하긴 한데 좀 느려서 모델 삭제는 주피터 인라인 문법으로 삭제하는걸 추천)
# !python -m model.invoke --config-name mdp3_config \
    invoke.video_path="./data/Mcst74e8S9U.mp4"
# Out:
# Loading weights: 100% 750/750 [02:03<00:00,  6.06it/s]
# Loading weights: 100% 888/888 [00:13<00:00, 64.41it/s]
# === Inference Setup ===
# Video       : /content/drive/MyDrive/GUARD_EXP_REPO/data/Mcst74e8S9U.mp4
# Model       : Qwen/Qwen3-VL-8B-Instruct
# Backend     : qwen3_vl
# DType       : bf16
# Local Store : ./model/repo
# Load Source : model/repo/Qwen__Qwen3-VL-8B-Instruct
# Frame Layer : model.FrameSelection.MDP3.selection.mdp3_sampling
# Prompt File : model/base/prompt.txt
# Query File  : model/base/query.txt
#
# Error executing job with overrides: ['invoke.video_path=./data/Mcst74e8S9U.mp4']
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/GUARD_EXP_REPO/model/invoke.py", line 200, in main
#     response = vlm.answer(
#                ^^^^^^^^^^^
#   File "/content/drive/MyDrive/GUARD_EXP_REPO/model/FrameSelection/MDP3/vlm.py", line 177, in answer
#     self.frame_selector(video_path=video_path, **selector_kwargs),
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/GUARD_EXP_REPO/model/FrameSelection/MDP3/selection.py", line 347, in mdp3_sampling
#     selected = mdp3_frame_selection(
#                ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/GUARD_EXP_REPO/model/FrameSelection/MDP3/selection.py", line 289, in mdp3_frame_selection
#     reward = _log_det_score(l_tilde, all_selected)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/GUARD_EXP_REPO/model/FrameSelection/MDP3/selection.py", line 184, in _log_det_score
#     sign, logabsdet = torch.linalg.slogdet(submatrix)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: linalg.slogdet: Low precision dtypes not supported. Got BFloat16
#
# Set the environment variable HYDRA_FULL_ERROR=1 for a complete stack trace.
