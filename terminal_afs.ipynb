# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 구글 드라이브 상에 코드 배포했던 저장위치로 이동

# %%
cd /content/drive/MyDrive/GUARD_EXP_REPO
# Out:
# /content/drive/MyDrive/GUARD_EXP_REPO

# %%
ls
# Out:
# config/  model/     requirements.launch.txt  setting.sh      utils/
# doc/     readme.md  requirements.txt         terminal.ipynb

# %% [markdown]
# 아래 스크립트로 프로젝트 의존성 맞추면 됨

# %%
# !sh setting.sh
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 151.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 334.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.
# ...

# %%
# !pip install "numpy<2.1"
# Out:
# ...
#   Using cached numpy-2.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Using cached numpy-2.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.2 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# ...

# %% [markdown]
# 다음 유틸로 영상 다운로드 가능 (롱이든 숏이든 다)

# %%
# !python -m utils.download https://www.youtube.com/shorts/Mcst74e8S9U
# Out:
# [youtube] Extracting URL: https://www.youtube.com/shorts/Mcst74e8S9U
# [youtube] Mcst74e8S9U: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] Mcst74e8S9U: Downloading android vr player API JSON
# [info] Mcst74e8S9U: Downloading 1 format(s): 137+140
# [download] Destination: /content/drive/MyDrive/GUARD_EXP_REPO/data/Mcst74e8S9U.f137.mp4
# [download] 100% of   39.21MiB in 00:00:04 at 9.78MiB/s
# [download] Destination: /content/drive/MyDrive/GUARD_EXP_REPO/data/Mcst74e8S9U.f140.m4a
# [download] 100% of    1.68MiB in 00:00:00 at 8.59MiB/s
# [Merger] Merging formats into "/content/drive/MyDrive/GUARD_EXP_REPO/data/Mcst74e8S9U.mp4"
# ...

# %%
# ./data에 저장된 영상 경로 확인, 혹시 모르니 코랩 익스텐션에 마운트된 구글 드라이브 상황까지 확인 해보기
# !ls ./data
# Out:
# Mcst74e8S9U.mp4

# %%
# 아래와 같이 .yaml 수정 없이 바로 cli로 옵션 선택 가능
# 모델 로드가 너무 느려지면 ./model/repo 지우고 그냥 새로 다운하는걸 추천 (왼쪽에 코랩 익스텐션에서도 삭제가 가능하긴 한데 좀 느려서 모델 삭제는 주피터 인라인 문법으로 삭제하는걸 추천)
# !python -m model.invoke --config-name afs \
    invoke.video_path="./data/Mcst74e8S9U.mp4"
# Out:
# ...
# Fetching 16 files: 100% 16/16 [02:20<00:00,  8.79s/it]
# Download complete: : 17.5GB [02:21, 124MB/s]
# Loading weights: 100% 750/750 [01:43<00:00,  7.24it/s]
# === Inference Setup ===
# Video       : /content/drive/MyDrive/GUARD_EXP_REPO/data/Mcst74e8S9U.mp4
# Model       : Qwen/Qwen3-VL-8B-Instruct
# Backend     : qwen3_vl
# DType       : bf16
# Local Store : ./model/repo
# Load Source : model/repo/Qwen__Qwen3-VL-8B-Instruct
# Frame Layer : model.FrameSelction.AFS.adaptive_frame_sampling
# Prompt File : model/base/prompt.txt
# Query File  : model/base/query.txt
#
# === Response ===
# Yes, there is pizza in the video. The main activity shown is the preparation of pizza, including spreading tomato sauce on dough, adding toppings like arugula, and finally tasting the finished pizza. The video focuses on the process of making and enjoying pizza in a kitchen setting.
#
# === Timing ===
# Elapsed     : 413.70s
# LLM Generate: 78.82s
# Non-LLM     : 334.88s
# Gen Tokens  : 57
# ...
